# %%
from selenium import webdriver
import time
# ActionChains 를 사용하기 위해서.
from selenium.webdriver import ActionChains
import pymysql

# %%
driver = webdriver.Chrome("../Data/chromedriverMac")
# driver = webdriver.Chrome("../Data/chromedriver")

# %%
# 경로 설정
driver.get('https://www.mangoplate.com/search/%EC%84%9C%EC%9A%B8')

# %%
# 경로 설정
driver.get('https://www.mangoplate.com/search/%EC%84%9C%EC%9A%B8')
xpathFilter = "/html/body/main/article/div[2]/div/div/section/div[1]/div[1]/button[1]"
regions = driver.find_elements_by_class_name('metro_btn')
xpathApply = '/html/body/main/article/div[2]/div/aside/div[2]/button[2]'
# 페이지 수
pages = driver.find_elements_by_tag_name('div.paging-container a')
# 한 페이지에 있는 매장 수 
stores = driver.find_elements_by_class_name('restaurant-item')

# %%
# 필터 클릭
element_filter = driver.find_element_by_xpath(xpathFilter).click()

# %%
# 지역 클릭
regions[0].click()

# %%
# 적용버튼 클릭
element_apply = driver.find_element_by_xpath(xpathApply).click()

# %%
regions = driver.find_elements_by_class_name('metro_btn')

# %%
driver.get('https://www.mangoplate.com/search/%EC%84%9C%EC%9A%B8')
element_filter = driver.find_element_by_xpath(xpathFilter).click()
# 지역들
regions = driver.find_elements_by_class_name('metro_btn')
print(regions[0].text)
# for region in regions:
print(regions[0].text)
driver.get('https://www.mangoplate.com/search/%EC%84%9C%EC%9A%B8')
element_filter = driver.find_element_by_xpath(xpathFilter).click()

# 지역들
regions = driver.find_elements_by_class_name('metro_btn')
region[0].click()
# Out:
# 가로수길
# 가로수길
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-ecb9ab6a4faf> in <module>
#      11 # 지역들
#      12 regions = driver.find_elements_by_class_name('metro_btn')
# ---> 13 region[0].click()
#
# TypeError: 'WebElement' object is not subscriptable

# %%
# 1페이지 크롤링
stores = driver.find_elements_by_xpath('/html/body/main/article/div[2]/div/div/section/div[3]/ul/li/div/figure/figcaption/div/a')

for index in range(0,20):
    stores = driver.find_elements_by_xpath('/html/body/main/article/div[2]/div/div/section/div[3]/ul/li/div/figure/figcaption/div/a')
    print(stores[index].text)
    
    stores[index].click()
#     time.sleep(1)
    # 크롤링 하고!
#     print(stores[index].text,"크롤링 완료")
    driver.back()
#     time.sleep(1)
# Out:
# 허브족발 (본점)
# 샐러드셀러
# 소이연남마오
# 호반
# 패스트리부티크 (서울신라호텔)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-238-acd946747629> in <module>
#      10     # 크롤링 하고!
#      11 #     print(stores[index].text,"크롤링 완료")
# ---> 12     driver.back()
#      13 #     time.sleep(1)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in back(self)
#     811             driver.back()
#     812         """
# --> 813         self.execute(Command.GO_BACK)
#     814
#     815     def forward(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# ...

# %%
driver = webdriver.Chrome("../Data/chromedriverMac")
# driver = webdriver.Chrome("../Data/chromedriver")
# 경로 설정
driver.get('https://www.mangoplate.com/search/%EC%84%9C%EC%9A%B8')

# %%
for page in range(0, 10):
    # 페이지 수
    pages = driver.find_elements_by_tag_name('div.paging-container a')
    print(pages[page].text, "페이지")
    pages[page].click()
    time.sleep(1)
    # 1페이지 크롤링
    stores = driver.find_elements_by_xpath('/html/body/main/article/div[2]/div/div/section/div[3]/ul/li/div/figure/figcaption/div/a')
    
    for index in range(0,20):
        stores = driver.find_elements_by_xpath('/html/body/main/article/div[2]/div/div/section/div[3]/ul/li/div/figure/figcaption/div/a')
        print(stores[index].text)
        inPageStoreName = stores[index].text
        stores[index].click()
    
        # 크롤링 하고!
#         print(inPageStoreName,"크롤링 완료")
        driver.back()
# Out:
# 1 페이지
# 스시소라 (광화문점)
# 타쿠미곤
# 미라이
# 시라카와
# 바위파스타바
# 맛짱조개
# 쿠나
# 스시카나에
# 파씨오네
# 쥬에
# 와라야키 쿠이신보
# 가담
# 알라프리마
# 팔레드 신
# 마루심
# 카와카츠
# 쿠이신보
# 야상해
# 부촌육회
# 유즈라멘
# 2 페이지
# 허브족발 (본점)
# 샐러드셀러
# 소이연남마오
# 호반
# 패스트리부티크 (서울신라호텔)
# 소세지전문점
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-242-48501e9250ba> in <module>
#      12         print(stores[index].text)
#      13         inPageStoreName = stores[index].text
# ---> 14         stores[index].click()
#      15
#      16         # 크롤링 하고!
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ...

# %%
driver.get('https://www.mangoplate.com/search/%EC%84%9C%EC%9A%B8')
# 페이지 수
pages = driver.find_elements_by_tag_name('div.paging-container a')
for page in pages:

    print(page.text, " 페이지")
    page.click()


    # 한 페이지에 있는 매장 수 
    stores = driver.find_elements_by_class_name('restaurant-item')
    stores[0].text
    for store in stores:
        print(store.text)
    count = 0
    for store in stores:
        if count == 0:
            count = count + 1
        else:
            driver.back()
        print(store.text)
        store.click()
        xpathName = '/html/body/main/article/div[1]/div[1]/div/section[1]/header/div[1]/span/h1'
        storeName = driver.find_element_by_xpath(xpathName).text

        xpathScore = '/html/body/main/article/div[1]/div[1]/div/section[1]/header/div[1]/span/strong/span'
        storeScore = driver.find_element_by_xpath(xpathScore).text

        xpathAddress = '/html/body/main/article/div[1]/div[1]/div/section[1]/table/tbody/tr[1]/td/text()'
        storeAddress = driver.find_element_by_xpath("/html/body/main/article/div[1]/div[1]/div/section[1]/table/tbody/tr[1]/td").text

        xpathTel = '/html/body/main/article/div[1]/div[1]/div/section[1]/table/tbody/tr[2]/td'
        storeTel = driver.find_element_by_xpath(xpathTel).text

        xpathCategory = '/html/body/main/article/div[1]/div[1]/div/section[1]/table/tbody/tr[3]/td/span'
        storeCategory = driver.find_element_by_xpath(xpathCategory).text

        xpathPriceRange = '/html/body/main/article/div[1]/div[1]/div/section[1]/table/tbody/tr[4]/td'
        priceRange = driver.find_element_by_xpath(xpathPriceRange).text

        # 메뉴 가져오기 
        menus = driver.find_elements_by_class_name('Restaurant_Menu')
        storeMenu = ''
        for menu in menus:
            storeMenu = storeMenu + ' /' +  menu.text
        storeMenu

        reviewPages = int(driver.find_element_by_xpath("/html/body/main/article/div[1]/div[1]/div/section[3]/header/h2/span[4]").text) / 5
        reviewPages = int(reviewPages)

#             for i in range(1,reviewPages):
#                 # RestaurantReviewList__MoreReviewButton
#                 # 리뷰 더보기 클릭
#                 for j in range(2):
#                     # id가 something 인 element 를 찾음
#                     some_tag = driver.find_element_by_class_name("RestaurantReviewList__MoreReviewButton")

#                     # somthing element 까지 스크롤
#                     action = ActionChains(driver)
#                     action.move_to_element(some_tag).perform()
#                     time.sleep(1)

#                 element_moreReview = driver.find_element_by_class_name("RestaurantReviewList__MoreReviewButton").click()
#                 time.sleep(1)

        storeReview = ''
        for element in driver.find_elements_by_class_name("RestaurantReviewItem__ReviewText"):
            storeReview = storeReview + ' /' + element.text

        print('매장명 : ', storeName, ",\n",
             '점수 : ', storeScore, ",\n",
              '주소 : ', storeAddress, ",\n",
              '전화번호 : ', storeTel, ",\n",
              '음식 종류 : ', storeCategory, ",\n",
              '가격대 : ', priceRange, ",\n",
              '메뉴 : ', storeMenu, ",\n",
              '리뷰 : ', storeReview, ",\n"
             )
# Out:
# 1  페이지
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-103-83c5ba38e287> in <module>
#      10     # 한 페이지에 있는 매장 수
#      11     stores = driver.find_elements_by_class_name('restaurant-item')
# ---> 12     stores[0].text
#      13     for store in stores:
#      14         print(store.text)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in text(self)
#      74     def text(self):
#      75         """The text of the element."""
# ---> 76         return self._execute(Command.GET_ELEMENT_TEXT)['value']
#      77
#      78     def click(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
# ...

# %%
driver.get('https://www.mangoplate.com/search/%EC%84%9C%EC%9A%B8')

# %%
# /html/body/main/article/div[2]/div/div/section/div[1]/div[1]/button[1]
# 필터버튼 클릭해주기
xpath = "/html/body/main/article/div[2]/div/div/section/div[1]/div[1]/button[1]"
element_filter = driver.find_element_by_xpath(xpath).click()

# %%
# /html/body/main/article/div[2]/div/aside/div[1]/div/div[3]/p[2]/span[1]/label
# /html/body/main/article/div[2]/div/aside/div[1]/div/div[3]/p[2]/span[2]/label
# 하위 지역 선택
xpath = '/html/body/main/article/div[2]/div/aside/div[1]/div/div[3]/p[2]/span[1]/label'
element_region = driver.find_element_by_xpath(xpath).click()

# %%
# /html/body/main/article/div[2]/div/aside/div[2]/button[2]
# 적용 버튼 누르기
xpath = '/html/body/main/article/div[2]/div/aside/div[2]/button[2]'
element_apply = driver.find_element_by_xpath(xpath).click()

# %%
# /html/body/main/article/div[2]/div/div/section/div[3]/ul/li[1]/div[1]/figure/figcaption/div/a/span
# /html/body/main/article/div[2]/div/div/section/div[3]/ul/li[1]/div[2]/figure/figcaption/div/a/span
# 식당 누르기
xpath = '/html/body/main/article/div[2]/div/div/section/div[3]/ul/li[1]/div[1]/figure/figcaption/div/a/span'
element_apply = driver.find_element_by_xpath(xpath).click()

# %%
# /html/body/main/article/div[1]/div[1]/div/section[1]/header/div[1]/span/h1
xpathName = '/html/body/main/article/div[1]/div[1]/div/section[1]/header/div[1]/span/h1'
storeName = driver.find_element_by_xpath(xpathName).text

# %%
# /html/body/main/article/div[1]/div[1]/div/section[1]/header/div[1]/span/strong/span
xpathScore = '/html/body/main/article/div[1]/div[1]/div/section[1]/header/div[1]/span/strong/span'
storeScore = driver.find_element_by_xpath(xpathScore).text
# Out:
# '4.8'

# %%
# /html/body/main/article/div[1]/div[1]/div/section[1]/table/tbody/tr[1]/td/text()
xpathAddress = '/html/body/main/article/div[1]/div[1]/div/section[1]/table/tbody/tr[1]/td/text()'
driver.find_element_by_xpath("/html/body/main/article/div[1]/div[1]/div/section[1]/table/tbody/tr[1]/td").text
# Out:
# '서울특별시 강남구 도산대로75길 15 노노빌딩 2F\n지번 서울시 강남구 청담동 96-22 노노빌딩 2F'

# %%
# /html/body/main/article/div[1]/div[1]/div/section[1]/table/tbody/tr[2]/td
xpathTel = '/html/body/main/article/div[1]/div[1]/div/section[1]/table/tbody/tr[2]/td'
driver.find_element_by_xpath(xpathTel).text
# Out:
# '02-516-3350'

# %%
# /html/body/main/article/div[1]/div[1]/div/section[1]/table/tbody/tr[3]/td/span
xpathCategory = '/html/body/main/article/div[1]/div[1]/div/section[1]/table/tbody/tr[3]/td/span'
driver.find_element_by_xpath(xpathCategory).text
# Out:
# '회 / 스시'

# %%
# /html/body/main/article/div[1]/div[1]/div/section[1]/table/tbody/tr[4]/td
xpathPriceRange = '/html/body/main/article/div[1]/div[1]/div/section[1]/table/tbody/tr[4]/td'
driver.find_element_by_xpath(xpathPriceRange).text
# Out:
# '4만원 이상'

# %%
# 메뉴 가져오기 
menus = driver.find_elements_by_class_name('Restaurant_Menu')
storeMenu = ''
for menu in menus:
    storeMenu = storeMenu + ' /' +  menu.text
storeMenu
# Out:
# ' /사시미8종 (2인) /마구로치즈아에 /양갈비 스미비 야끼 /노도구로 시오 야끼 /규 스테이크'

# %%
reviewPages = int(driver.find_element_by_xpath("/html/body/main/article/div[1]/div[1]/div/section[3]/header/h2/span[4]").text) / 5
reviewPages = int(reviewPages)

# %%
for i in range(1,reviewPages):
    # RestaurantReviewList__MoreReviewButton
    # 리뷰 더보기 클릭
    for j in range(2):
        # id가 something 인 element 를 찾음
        some_tag = driver.find_element_by_class_name("RestaurantReviewList__MoreReviewButton")

        # somthing element 까지 스크롤
        action = ActionChains(driver)
        action.move_to_element(some_tag).perform()
        time.sleep(1)
    
    element_moreReview = driver.find_element_by_class_name("RestaurantReviewList__MoreReviewButton").click()
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-133-98993c933ae1> in <module>
# ----> 1 for i in range(1,reviewPages):
#       2     # RestaurantReviewList__MoreReviewButton
#       3     # 리뷰 더보기 클릭
#       4     for j in range(2):
#       5         # id가 something 인 element 를 찾음
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
for element in driver.find_elements_by_class_name("RestaurantReviewItem__ReviewText"):
    print(element.text)
# Out:
# 미라이 크리스마스 코스
# 마구로치즈아에 : 녹진하니 혀에서 녹는맛이 일품이다. 기린과 궁합이 좋았으나, 싱겁게 먹는 내 입에는 살짝 짠편.
#
# 사바산도 : 솔직히 기대가 가장 컸던 음식, 기대한 대로의 맛이었다. 고등어의 강한 풍미를 매쉬드 포테이토와 빵의 고소한 맛이 감싸며, 단무지와 시소가 마무리하는 완벽한 맛이었다. 이음식도 기린과 함께했는데, 고등어가 입에 있는채로 맥주를 먹으니 비린맛이 올라온것이 아쉬운점.
#
# 우니 : 계절에 비해 훌륭한 맛을 자랑한다. 상태가 좋대서 시켜봤는데, 군내도 안나고 깔끔하고 부드러운 풍미가 아주 입에 맞았다. 내가 어린 입맛이라 그런지 고구마 소츄인 키로쿠 무여과와의 궁합은 그저 그랬다. 차라리 하이볼로 산미를 좀 주는것이 낫지 않았을까 싶다.
# 특별한 날 꼭 다시 오고 싶은 곳 ㅜ 가격만 아니면.. 일주일에 한 번은 가고싶다
# 이만한 이자카야 발견하기 너무 힘들죠. 특색 있는 레시피로 일식을 좋아하는 사람들에겐 이미 유명한 식당!
#
# 특히 고등어샌드위치가 너무 유명한데요. 이 음식을 먹으면, 요리가 얼마나 창의적인 작업인지 온몸으로 느끼게 됩니다.
#
# 붉은기가 도는 기름진 생선과 으깬 감자가 한 번에 조화를 이룰지 누가 상상했을까요.ㅠ 비린내에 아주 예민하지만 않다면 누구든 편히 사바산도라는 새로운 음식에 도전하게 하는 멋진 시도 같아요. 맥주든, 위스키든, 사케든 어디에나 잘 어울리는 맛이라고 생각합니다.
#
# 그외 구이나 탕 메뉴도 깔끔하니 충분히 방문해볼만한 식당이예요! 맛있는 음식에 반주하고 싶은 날, 예약을 추천합니다. :)
# 맛있어요 맛있는데.. 막 엄청 감동이 있진 않고 딱 그냥 괜찮아요 근데 4.8 정도는 아닌것 같아요 전 그냥 갓포를 갈래요...

# %%
# MySQL Connection
conn = pymysql.connect(host = "database-2.cotrd7tmeavd.ap-northeast-2.rds.amazonaws.com", user = "root", password = "qwer1234", db = "firstkorea", charset = "utf8")

# %%
# Connection으로 부터 Cursor 생성

curs = conn.cursor()

# %%
# SQL문장

sql = "INSERT INTO foodstore (storeName, storeScore, storeAddress, storeTel, storeCategory, priceRange, storeMenu, storeReview, storeImage) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)"

# %%
# Insert 실행

curs.execute(sql, (storeName, storeScore, storeAddress, storeTel, storeCategory, priceRange, storeMenu, storeReview, storeImage))
# Out:
# 1

# %%
conn.commit()

# %%
# SQL문장

sql = "select * from food"
curs.execute(sql)
# Out:
# 1

# %%
# Data Fetch

rows = curs.fetchall()
print(rows)
# Out:
# ((0, '스시소라'),)

# %%
# Connection 종료

conn.close()

# %%
# 한 페이지에 있는 매장 수 
driver.find_elements_by_class_name('restaurant-item')
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="537255499ebf4ca15cc16202d8897959", element="bdbd33fd-208f-407b-bb45-07726735e564")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="537255499ebf4ca15cc16202d8897959", element="26ec338d-fee3-4caf-97d6-e1bc4d015882")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="537255499ebf4ca15cc16202d8897959", element="68855bfd-475a-41a0-ad7a-e1ca3a59d09c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="537255499ebf4ca15cc16202d8897959", element="1c9249b2-304c-4d09-93e2-f7b1f0330919")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="537255499ebf4ca15cc16202d8897959", element="70237dea-2860-4116-ad48-d24ee2a037f3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="537255499ebf4ca15cc16202d8897959", element="8c8889e7-4f8a-4b44-b485-360aed5248c4")>,
# ...

# %%
# 페이지 수
len(driver.find_elements_by_tag_name('div.paging-container a'))
# Out:
# 10

# %%
int(33/5)
# Out:
# 6

# %%
50/5
# Out:
# 10.0

# %%
driver = webdriver.Chrome("../Data/chromedriverMac")
# driver = webdriver.Chrome("../Data/chromedriver")
# 경로 설정
driver.get('https://www.mangoplate.com/search/%EC%84%9C%EC%9A%B8')

# %%
# MySQL Connection
conn = pymysql.connect(host = "database-2.cotrd7tmeavd.ap-northeast-2.rds.amazonaws.com", user = "root", password = "qwer1234", db = "firstkorea", charset = "utf8")
# Connection으로 부터 Cursor 생성

curs = conn.cursor()
# SQL문장

sql = "INSERT INTO foodstore (storeName, storeScore, storeAddress, storeTel, storeCategory, priceRange, storeMenu, storeReview, storeImage) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)"

# Insert 실행

# curs.execute(sql, (storeName, storeScore, storeAddress, storeTel, storeCategory, priceRange, storeMenu, storeReview, storeImage))
# conn.commit()

for page in range(0, 10):
# for page in range(0, 1):
    # 페이지 수
    pages = driver.find_elements_by_tag_name('div.paging-container a')
    print(pages[page].text, "페이지")
    pages[page].click()
    time.sleep(1)
    # 1페이지 크롤링
    stores = driver.find_elements_by_xpath('/html/body/main/article/div[2]/div/div/section/div[3]/ul/li/div/figure/figcaption/div/a')
    
    for index in range(0,20):
#     for index in range(0,1):
        stores = driver.find_elements_by_xpath('/html/body/main/article/div[2]/div/div/section/div[3]/ul/li/div/figure/figcaption/div/a')
        print(stores[index].text)
        inPageStoreName = stores[index].text
        stores[index].click()
    
        # -------------------------------------------------------------------------------------------------------------------------
        # 매장 정보 크롤링
        img = driver.find_element_by_css_selector('img.center-croping')
        storeImage = img.get_attribute('src').split('.jpg')[0] + '.jpg'
        
        
        xpathName = '/html/body/main/article/div[1]/div[1]/div/section[1]/header/div[1]/span/h1'
        storeName = driver.find_element_by_xpath(xpathName).text

        xpathScore = '/html/body/main/article/div[1]/div[1]/div/section[1]/header/div[1]/span/strong/span'
        storeScore = driver.find_element_by_xpath(xpathScore).text

        xpathAddress = '/html/body/main/article/div[1]/div[1]/div/section[1]/table/tbody/tr[1]/td/text()'
        storeAddress = driver.find_element_by_xpath("/html/body/main/article/div[1]/div[1]/div/section[1]/table/tbody/tr[1]/td").text

        xpathTel = '/html/body/main/article/div[1]/div[1]/div/section[1]/table/tbody/tr[2]/td'
        storeTel = driver.find_element_by_xpath(xpathTel).text

        xpathCategory = '/html/body/main/article/div[1]/div[1]/div/section[1]/table/tbody/tr[3]/td/span'
        storeCategory = driver.find_element_by_xpath(xpathCategory).text

        xpathPriceRange = '/html/body/main/article/div[1]/div[1]/div/section[1]/table/tbody/tr[4]/td'
        priceRange = driver.find_element_by_xpath(xpathPriceRange).text

        # 메뉴 가져오기 
        menus = driver.find_elements_by_class_name('Restaurant_Menu')
        storeMenu = ''
        for menu in menus:
            storeMenu = storeMenu + ' /' +  menu.text
        storeMenu

        reviewPages = int(driver.find_element_by_xpath("/html/body/main/article/div[1]/div[1]/div/section[3]/header/h2/span[4]").text) / 5
        reviewPages = int(reviewPages)

        for i in range(1,reviewPages):
            # RestaurantReviewList__MoreReviewButton
            # 리뷰 더보기 클릭
            for j in range(2):
                # id가 something 인 element 를 찾음
                some_tag = driver.find_element_by_class_name("RestaurantReviewList__MoreReviewButton")

                # somthing element 까지 스크롤
                action = ActionChains(driver)
                action.move_to_element(some_tag).perform()
                time.sleep(1)

            element_moreReview = driver.find_element_by_class_name("RestaurantReviewList__MoreReviewButton").click()
            time.sleep(1)

        storeReview = ''
        for element in driver.find_elements_by_class_name("RestaurantReviewItem__ReviewText"):
            storeReview = storeReview + ' /' + element.text

        print('매장 사진 소스 : ', storeImage, ",\n",
            '매장명 : ', storeName, ",\n",
             '점수 : ', storeScore, ",\n",
              '주소 : ', storeAddress, ",\n",
              '전화번호 : ', storeTel, ",\n",
              '음식 종류 : ', storeCategory, ",\n",
              '가격대 : ', priceRange, ",\n",
              '메뉴 : ', storeMenu, ",\n",
              '리뷰 : ', storeReview, "\n"
             )
        
        # -------------------------------------------------------------------------------------------------------------------------
        print(inPageStoreName,"크롤링 완료")
        # Insert 실행

        curs.execute(sql, (storeName, storeScore, storeAddress, storeTel, storeCategory, priceRange, storeMenu, storeReview, storeImage))
        conn.commit()
        driver.back()
        
        

# Connection 종료

conn.close()
# Out:
# 1 페이지
# 스시소라 (광화문점)
# 매장 사진 소스 :  https://mp-seoul-image-production-s3.mangoplate.com/54303_1528720802986009.jpg ,
#  매장명 :  스시소라 ,
#  점수 :  4.8 ,
#  주소 :  서울특별시 종로구 종로 19 B116 B-1호
# 지번 서울시 종로구 종로1가 24 B116 B-1호 ,
#  전화번호 :  02-733-8400 ,
#  음식 종류 :  정통 일식 / 일반 일식 ,
#  가격대 :  4만원 이상 ,
#  메뉴 :   /런치 카운터 오마카세 /런치 스시코스 /디너 카운터 오마카세 /디너 스시코스 ,
#  리뷰 :   /정말 맛있고 정갈하게 나옵니다 마지막에 나온 아이스크림까지 완벽했어요 초밥을 입에 넣는 순간 바로 녹는 것 같이 느껴질 정도이고, 중간중간 계속 물과 국을 리필해주셔서 좋았습니다~ /개판!! 오랫동안 가보고 싶은 집이었습니다!!! 아버님이 스시 좋아하셔서 오랫만에 큰 맘먹고 방문 했습니다!! 역시!! 스시는 스시 소라더군요! 정확히 어떤 포인트에서 이집이 개판인지 말씀드릴게요
#
# 1. 점심 11:27분에 예약했을 때 직원이 여섯시 반으로 예약을 받음 (이집 예약은 2부가 7:15분 시작이라고 함)
# 2. 제가 주류는 무엇이 있나요 라고 물어보고 있는 도중 직원이 전화를 끊음... 뭐... 그럴 수 있죠
# 3. 6:30에 방문 했더니 예약이 안되어있다고 함
# 4. 직원이... “어디다” 전화하셨어요? 라고 물어 봄
# 5. 예약한 번호로 다시 전화함 심지어 그 와중에 11:27분 전화통화 3분 (예약 당시) 한거 보여 줌, 그랬더니
# 직원이 “번호는 맞는데” 기록이 없다며 예약 장부를 보여 줌
# 6. 이 실랑이를 본 책임자가 5분 내에 자리 만들어 주겠다해서 화가 좀 풀림, 그리고 10분 후에 자리가 날 때 까지 직원들 중 아무도 다리 불편해서 목발 짚고 온 사람한테 앉으라던가 하는 말을 하지 않음
# ...

# %%
img = driver.find_element_by_css_selector('img.center-croping')
string = img.get_attribute('src').split('.jpg')[0] + '.jpg'
string
# Out:
# 'https://mp-seoul-image-production-s3.mangoplate.com/54303_1528720802986009.jpg'

# %%
print('매장 사진 소스 : ', storeImage, ",\n",
            '매장명 : ', storeName, ",\n",
             '점수 : ', storeScore, ",\n",
              '주소 : ', storeAddress, ",\n",
              '전화번호 : ', storeTel, ",\n",
              '음식 종류 : ', storeCategory, ",\n",
              '가격대 : ', priceRange, ",\n",
              '메뉴 : ', storeMenu, ",\n",
              '리뷰 : ', storeReview, "\n"
             )
curs.execute(sql, (storeName, storeScore, storeAddress, storeTel, storeCategory, priceRange, storeMenu, storeReview, storeImage))
# Out:
# 매장 사진 소스 :  https://mp-seoul-image-production-s3.mangoplate.com/54303_1528720802986009.jpg ,
#  매장명 :  스시소라 ,
#  점수 :  4.8 ,
#  주소 :  서울특별시 종로구 종로 19 B116 B-1호
# 지번 서울시 종로구 종로1가 24 B116 B-1호 ,
#  전화번호 :  02-733-8400 ,
#  음식 종류 :  정통 일식 / 일반 일식 ,
#  가격대 :  4만원 이상 ,
#  메뉴 :   /런치 카운터 오마카세 /런치 스시코스 /디너 카운터 오마카세 /디너 스시코스 ,
#  리뷰 :   /정말 맛있고 정갈하게 나옵니다 마지막에 나온 아이스크림까지 완벽했어요 초밥을 입에 넣는 순간 바로 녹는 것 같이 느껴질 정도이고, 중간중간 계속 물과 국을 리필해주셔서 좋았습니다~ /개판!! 오랫동안 가보고 싶은 집이었습니다!!! 아버님이 스시 좋아하셔서 오랫만에 큰 맘먹고 방문 했습니다!! 역시!! 스시는 스시 소라더군요! 정확히 어떤 포인트에서 이집이 개판인지 말씀드릴게요
#
# 1. 점심 11:27분에 예약했을 때 직원이 여섯시 반으로 예약을 받음 (이집 예약은 2부가 7:15분 시작이라고 함)
# 2. 제가 주류는 무엇이 있나요 라고 물어보고 있는 도중 직원이 전화를 끊음... 뭐... 그럴 수 있죠
# 3. 6:30에 방문 했더니 예약이 안되어있다고 함
# 4. 직원이... “어디다” 전화하셨어요? 라고 물어 봄
# 5. 예약한 번호로 다시 전화함 심지어 그 와중에 11:27분 전화통화 3분 (예약 당시) 한거 보여 줌, 그랬더니
# 직원이 “번호는 맞는데” 기록이 없다며 예약 장부를 보여 줌
# 6. 이 실랑이를 본 책임자가 5분 내에 자리 만들어 주겠다해서 화가 좀 풀림, 그리고 10분 후에 자리가 날 때 까지 직원들 중 아무도 다리 불편해서 목발 짚고 온 사람한테 앉으라던가 하는 말을 하지 않음
# ...

# %%
sql
# Out:
# 'INSERT INTO food (storeName, storeScore, storeAddress, storeTel, storeCategory, priceRange, storeMenu, storeReview, storeImage) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)'
